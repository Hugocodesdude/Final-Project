# %% [markdown]
# # Cities Visualisations

# %%
import os
import requests
from bs4 import BeautifulSoup as bs4
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import glob

import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import seaborn as sns
import plotly.figure_factory as ff

import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

from plotly.subplots import make_subplots

# %% [markdown]
# # BCN

# %%
# read file & save to variable 
bcn_compact_merge = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/barcelona/bcn_compact/bcn_compact_merge.csv")

# %%
bcn_compact_merge
# Out:
#           city  Year  Month AirPollutant UnitOfMeasurement  Concentration
# 0    barcelona  2013      1           CO             mg/m3       0.475550
# 1    barcelona  2013      2           CO             mg/m3       0.414404
# 2    barcelona  2013      3           CO             mg/m3       0.395472
# 3    barcelona  2013      4           CO             mg/m3       0.397743
# 4    barcelona  2013      5           CO             mg/m3       0.351725
# ..         ...   ...    ...          ...               ...            ...
# 383  barcelona  2020      9          NO2             µg/m3      26.070494
# 384  barcelona  2020     10          NO2             µg/m3      27.645291
# 385  barcelona  2020     11          NO2             µg/m3      30.711480
# 386  barcelona  2020     12          NO2             µg/m3      27.976719
# 387  barcelona  2021      1          NO2             µg/m3      23.526316
#
# [388 rows x 6 columns]

# %% [markdown]
# # VAL

# %%
# read file & save to variable 
val_compact_merge = pd.read_csv("///Users/hugosaccount/Desktop/IronHack/final_project/data/cities/valencia/val_combined/val_compact_merge.csv")

# %%
val_compact_merge
# Out:
#          city  Year  Month AirPollutant UnitOfMeasurement  Concentration
# 0    valencia  2013      1        PM2.5             µg/m3       8.166845
# 1    valencia  2013      2        PM2.5             µg/m3       8.396848
# 2    valencia  2013      3        PM2.5             µg/m3       8.719276
# 3    valencia  2013      4        PM2.5             µg/m3      11.289735
# 4    valencia  2013      5        PM2.5             µg/m3       8.950336
# ..        ...   ...    ...          ...               ...            ...
# 383  valencia  2020      9           CO             mg/m3       0.137414
# 384  valencia  2020     10           CO             mg/m3       0.150489
# 385  valencia  2020     11           CO             mg/m3       0.170800
# 386  valencia  2020     12           CO             mg/m3       0.155791
# 387  valencia  2021      1           CO             mg/m3       0.100000
#
# [388 rows x 6 columns]

# %% [markdown]
# # MAD

# %%
# read file & save to variable 
mad_compact_merge = pd.read_csv("/Users/hugosaccount/Desktop/IronHack/final_project/data/cities/madrid/mad_compact/mad_compact_merge.csv")

# %%
mad_compact_merge
# Out:
#        city  Year  Month AirPollutant UnitOfMeasurement  Concentration
# 0    madrid  2013      1          NO2             µg/m3      44.323358
# 1    madrid  2013      2          NO2             µg/m3      38.340268
# 2    madrid  2013      3          NO2             µg/m3      28.545036
# 3    madrid  2013      4          NO2             µg/m3      26.662458
# 4    madrid  2013      5          NO2             µg/m3      25.629202
# ..      ...   ...    ...          ...               ...            ...
# 383  madrid  2020      9           CO             mg/m3       0.239143
# 384  madrid  2020     10           CO             mg/m3       0.335646
# 385  madrid  2020     11           CO             mg/m3       0.440873
# 386  madrid  2020     12           CO             mg/m3       0.333089
# 387  madrid  2021      1           CO             mg/m3       0.200000
#
# [388 rows x 6 columns]

# %% [markdown]
# # Spanish Cities

# %%
# Emtpy plots
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(25,10))

# For each plot, plot it somwhere
sns.lineplot(data=bcn_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[0])
sns.lineplot(data=val_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[1])
sns.lineplot(data=mad_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Concentration'>

# %% [markdown]
# # Smart Cities

# %%
# AMS
ams_compact_merge = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/amsterdam/ams_combined/ams_compact_merge.csv")

# %%
# Emtpy plots
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(25,10))

# For each plot, plot it somwhere
sns.lineplot(data=bcn_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[0])
sns.lineplot(data=cop_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[1])
sns.lineplot(data=ams_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 6>()
#       4 # For each plot, plot it somwhere
#       5 sns.lineplot(data=bcn_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[0])
# ----> 6 sns.lineplot(data=cop_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[1])
#       7 sns.lineplot(data=ams_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[2])
#
# NameError: name 'cop_compact_merge' is not defined

# %% [markdown]
# # COP

# %%
# read file & save to variable 
cop_compact_merge = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/copenhagen/cop_combined/cop_compact_merge.csv")

# %%
cop_compact_merge

# %% [markdown]
# # AMS

# %%
# read file & save to variable 
ams_compact_co_newdate = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/amsterdam/ams_compact_co_newdate.csv")

# %%
ams_compact_co_newdate

# %%
fig = px.line(ams_compact_co_newdate, x="new date", y="Concentration", color='AirPollutant')
fig.show()

# %%
fig = px.line(ams_compact_co_newdate, x='new date', y='Concentration')
fig.update_xaxes(ticks= "outside",
                 ticklabelmode= "period", 
                 tickcolor= "black", 
                 ticklen=10, 
                 minor=dict(
                     ticklen=4,  
                     dtick=7*24*60*60*1000,  
                     tick0="2016-07-03", 
                     griddash='dot', 
                     gridcolor='white')
                )

fig.show()

# %%
# Emtpy plots
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(25,10))

# For each plot, plot it somwhere
sns.lineplot(data=bcn_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[0])
sns.lineplot(data=cop_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[1])
sns.lineplot(data=ams_compact_merge, x="Year", y="Concentration", hue="AirPollutant", ax=axs[2])

# %% [markdown]
# # BCN Year Merge

# %%
bcn_compact_merge_1

# %%
bcn_compact_merge_year = bcn_compact_merge.groupby(['city', 'Year','AirPollutant'])['Concentration'].mean()

# %%
bcn_compact_merge_year

# %%
pd.DataFrame(bcn_compact_merge_year)

# %%
bcn_compact_merge_year.reset_index(drop=True)

# %%
#Saving compact version
bcn_compact_merge_year.to_csv("/Users/hugosaccount/Desktop/IronHack/final_project/data/cities/barcelona/bcn_compact_merge_year.csv")

# %%
#Reading compact version 
bcn_compact_merge_year = pd.read_csv("/Users/hugosaccount/Desktop/IronHack/final_project/data/cities/barcelona/bcn_compact_merge_year.csv")

# %%
bcn_compact_merge_year

# %%
fig = px.line(bcn_compact_merge_year, x="Year", y="Concentration", color='AirPollutant')
fig.show()

# %%
fig = make_subplots(rows=1, cols=3, shared_yaxes=True)


bcn_compact_merge_1 = bcn_compact_merge.sort_values(by=["Year"])
val_compact_merge_1 = val_compact_merge.sort_values(by=["Year"])
mad_compact_merge_1 = mad_compact_merge.sort_values(by=["Year"])



fig = px.line(bcn_compact_merge_1, x='Year', y='Concentration')
fig.add_trace(go.Line(x=val_compact_merge_1['Year'], y=val_compact_merge_1['Concentration']), row=1, col=2)
fig.add_trace(go.Line(x=mad_compact_merge_1['Year'], y=mad_compact_merge_1['Concentration']), row=1, col=3)


fig.show()

# %%
from datetime import datetime

# %%
bcn_compact_merge_1["Year_2"] = bcn_compact_merge_1['Year'].map(datetime.toordinal)

# %%
fig = make_subplots(rows=1, cols=3)

df = px.data.gapminder().query("continent=='Oceania'")
fig = px.line(df, x="year", y="lifeExp", color='country')
fig.show()




fig.show()

# %%
fig = px.line(bcn_compact_merge, x="Year", y="Concentration", color='AirPollutant')
fig.show()

# %%
df = px.data.tips()
fig = make_subplots(rows=1, cols=3)
fig.add_trace(go.Line(bcn_compact_merge, x='Year', y='Concentration', color='AirPollutant'), row=1, col=1)

# %%
# read file & save to variable 
amsterdam_combined_co_day = pd.read_csv("/Users/hugosaccount/Desktop/IronHack/final_project/data/cities/amsterdam/amsterdam_co/amsterdam_combined_co/amsterdam_combined_co_day.csv")

# %%
amsterdam_combined_co_day

# %%
amsterdam_combined_co_day = amsterdam_combined_co_day.sort_values(by=["Day"])
fig = px.line(amsterdam_combined_co_day, x="Day", y="Concentration", color='AirPollutant')
fig.show()

# %%
#Reading compact version 
ams_compact_newtime_merge = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/amsterdam/ams_combined_newdate/ams_compact_newtime_merge.csv")

# %%
#Reading compact version 
ams_compact_co_newdate = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/amsterdam/ams_combined_newdate/ams_compact_co_newdate.csv")

# %%
ams_compact_co_newdate

# %%
fig = px.line(ams_compact_co_newdate, x="new date", y="Concentration")
fig.show()

# %%
ams_compact_newtime_merge

# %%
df

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

app = Dash(__name__)


app.layout = html.Div([
    html.H4('Amsterdam Pollution Breakdown '),
    dcc.Graph(id="time-series-chart"),
    html.P("Select stock:"),
    dcc.Dropdown(
        id="ticker",
        options=["CO", "PM2.5", "PM10", "NO2"],
        value="CO",
        clearable=False,
    ),
])


@app.callback(
    Output("time-series-chart", "figure"), 
    Input("ticker", "value"))

def display_time_series(ticker):
    fig = px.line(ams_compact_newtime_merge, x='new date', y="Concentration")
    return fig

# %tb
app.run_server(debug=False,port='8055', use_reloader=False)

# %% [markdown]
# # CO/ BCN, MAD, VAL

# %%
# BCN CO
bcn_compact_c0_newdate = pd.read_csv("//Users/hugosaccount/Desktop/IronHack/final_project/data/cities/barcelona/bcn_compact_newdate/bcn_compact_c0_newdate.csv")

# %%
bcn_compact_c0_newdate

# %%
#MAD CO
mad_compact_co_newdate = pd.read_csv("///Users/hugosaccount/Desktop/IronHack/final_project/data/cities/madrid/mad_merge/mad_combined_pm10_newdate.csv")

# %%
#VAL CO
val_compact_co_newdate = pd.read_csv("///Users/hugosaccount/Desktop/IronHack/final_project/data/cities/valencia/val_compact_newdate/val_compact_c0_newdate.csv")

# %%
fig = make_subplots(rows=1, cols=3, shared_yaxes=True)




fig.add_trace(go.Line(x=bcn_compact_c0_newdate['new date'], y=bcn_compact_c0_newdate['Concentration']), row=1, col=1)
fig.add_trace(go.Line(x=mad_compact_co_newdate['new date'], y=mad_compact_co_newdate['Concentration']), row=1, col=2)
fig.add_trace(go.Line(x=val_compact_co_newdate['new date'], y=val_compact_co_newdate['Concentration']), row=1, col=3)


fig.show()

# %% [markdown]
# # Spanish Cities

# %%
#Spanish cities 
spanish_cities  = pd.read_csv("/Users/hugosaccount/Desktop/IronHack/final_project/data/cities/spanish_cities/spanish_cities.csv")

# %%
spanish_cities

# %%
import plotly.express as px
df = spanish_cities
fig = px.line(df, x="new date", y="Concentration", color="AirPollutant", facet_col="city", facet_row="AirPollutant")
fig.show()

# %%
df = spanish_cities
fig = px.scatter(spanish_cities, x="city", y="Concentration", animation_frame="new date",
                 
           color="AirPollutant", hover_name="city",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
fig["layout"].pop("updatemenus") # optional, drop animation buttons
fig.show()

# %% [markdown]
# # Smart Cities
